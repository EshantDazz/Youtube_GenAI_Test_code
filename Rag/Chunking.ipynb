# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import PyPDFLoader

# %%
### Split documents and create Documents

# %%
loader = PyMuPDFLoader("/Users/eshantdas/Downloads/field-guide-to-data-science.pdf")
data = loader.load()
data[:5]
# Out:
# [Document(metadata={'source': '/Users/eshantdas/Downloads/field-guide-to-data-science.pdf', 'file_path': '/Users/eshantdas/Downloads/field-guide-to-data-science.pdf', 'page': 0, 'total_pages': 126, 'format': 'PDF 1.4', 'title': 'The Field Guide to Data Science', 'author': 'Booz Allen Hamilton', 'subject': 'The Field Guide to Data Science', 'keywords': 'The Field Guide to Data Science', 'creator': 'Adobe InDesign CC 2015 (Macintosh)', 'producer': 'Mac OS X 10.12.4 Quartz PDFContext', 'creationDate': "D:20170501173004Z00'00'", 'modDate': "D:20170501173004Z00'00'", 'trapped': ''}, page_content=''),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter,TokenTextSplitter,CharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=10000, chunk_overlap=600)
splits_character = text_splitter.split_documents(data)

# %%
text_splitter=TokenTextSplitter(chunk_size=10000, chunk_overlap=600)
splits_token=text_splitter.split_documents(data)

# %%
print(splits_token[5].page_content)
print(len(splits_token[5].page_content))
# Out:
# ACKNOWLEDGEMENTS
# We would like to express our sincerest gratitude to
# all those who have made The Field Guide to Data
# Science such a success.
# Thank you to the nearly 15,000
# people who have downloaded
# the digital copy from our website
# and the 100+ people who have
# connected with The Field Guide
# on our GitHub page. We have
# been overwhelmed by the
# popularity of the work within the
# Data Science community.
# Thank you to all of the
# practitioners who are using The
# Field Guide as a resource. We are
# excited to know that the work has
# had such a strong influence, from
# shaping technical approaches to
# serving as the foundation for the
# very definition and role of Data
# Science within major government
# and commercial organizations.
# Thank you to the educators and
# academics who have incorporated
# The Field Guide into your course
# work. We appreciate your trusting
# this guide as a way to introduce
# your students to Data Science.
# ...

# %%
print(splits_character[5].page_content)
print(len(splits_character[5].page_content))
# Out:
# ACKNOWLEDGEMENTS
# We would like to express our sincerest gratitude to
# all those who have made The Field Guide to Data
# Science such a success.
# Thank you to the nearly 15,000
# people who have downloaded
# the digital copy from our website
# and the 100+ people who have
# connected with The Field Guide
# on our GitHub page. We have
# been overwhelmed by the
# popularity of the work within the
# Data Science community.
# Thank you to all of the
# practitioners who are using The
# Field Guide as a resource. We are
# excited to know that the work has
# had such a strong influence, from
# shaping technical approaches to
# serving as the foundation for the
# very definition and role of Data
# Science within major government
# and commercial organizations.
# Thank you to the educators and
# academics who have incorporated
# The Field Guide into your course
# work. We appreciate your trusting
# this guide as a way to introduce
# your students to Data Science.
# ...

# %%
from dotenv import load_dotenv
load_dotenv('/Users/eshantdas/Desktop/YOutube_scripts/myenv/.env')
# Out:
# True

# %% [markdown]
# ## Semantic Chunking

# %%
loader = PyMuPDFLoader("/Users/eshantdas/Downloads/field-guide-to-data-science.pdf")
data = loader.load()
data[:5]

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_cohere import CohereEmbeddings
embeddings = CohereEmbeddings(
    model="embed-english-light-v3.0"
)  

text_splitter = SemanticChunker(embeddings)

# %%
docs = text_splitter.split_documents(data)

# %%
docs
# Out:
# [Document(metadata={'source': '/Users/eshantdas/Downloads/field-guide-to-data-science.pdf', 'file_path': '/Users/eshantdas/Downloads/field-guide-to-data-science.pdf', 'page': 0, 'total_pages': 126, 'format': 'PDF 1.4', 'title': 'The Field Guide to Data Science', 'author': 'Booz Allen Hamilton', 'subject': 'The Field Guide to Data Science', 'keywords': 'The Field Guide to Data Science', 'creator': 'Adobe InDesign CC 2015 (Macintosh)', 'producer': 'Mac OS X 10.12.4 Quartz PDFContext', 'creationDate': "D:20170501173004Z00'00'", 'modDate': "D:20170501173004Z00'00'", 'trapped': ''}, page_content=''),
# ...

# %% [markdown]
# ### Using Create Documents

# %%
"https://www.youtube.com/watch?v=n0uPzvGTFI0"
# Out:
# 'https://www.youtube.com/watch?v=n0uPzvGTFI0'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load example document
with open("/Users/eshantdas/Desktop/YOutube_scripts/Files/datas.txt") as f:
    state_of_the_union = f.read()

text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=20,
    is_separator_regex=False,
)
texts = text_splitter.create_documents([state_of_the_union])
print(texts[0])
print(texts[1])
# Out:
# page_content='nformation that I can see on here is the fact that there's that one and Stuart's went out to attend'
# page_content='went out to attend t'

# %%
texts
# Out:
# [Document(page_content="nformation that I can see on here is the fact that there's that one and Stuart's went out to attend"),
#  Document(page_content='went out to attend t'),
#  Document(page_content='Right. Okay so.\n{Caller} - 03:15'),
#  Document(page_content='I offered the office photographs yesterday at the work that has been on the eighth.\n{Agent} - 03:25'),
#  Document(page_content='{Agent} - 03:25\nRight.\n{Agent} - 03:30'),
#  Document(page_content="So what's happened is that the the rocks is that he's actually doing work on there and they have"),
#  Document(page_content="there and they have planed the site. So they'll take obviously that means they've taken the top"),
#  Document(page_content='taken the top level off for the for the work for the area to be resurfaced.'),
#  Document(page_content='{Agent} - 03:46'),
#  Document(page_content="So it's in the process of being re surface at the moment, so that's the reason why it's uneven."),
# ...

# %%
'https://python.langchain.com/v0.2/docs/how_to/recursive_text_splitter/'
# Out:
# 'https://python.langchain.com/v0.2/docs/how_to/recursive_text_splitter/'

# %%
from langchain_text_splitters import TokenTextSplitter

# %%
text_splitter = TokenTextSplitter(chunk_size=1000, chunk_overlap=500)

texts = text_splitter.split_text(state_of_the_union)
len(texts)
# Out:
# 537

# %%
from langchain_experimental.text_splitter import SemanticChunker


text_splitter = SemanticChunker(embeddings)
